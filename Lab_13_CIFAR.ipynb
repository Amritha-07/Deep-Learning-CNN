# %%
from tensorflow.keras import datasets
from keras.models import Sequential
from keras.layers import Flatten, Dense, Conv2D, MaxPooling2D
import matplotlib.pyplot as plt
from keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

# %%
plt.matshow(x_train[1])

# %%
x_train[1].shape
# Out:
# (32, 32, 3)

# %%
model = Sequential()
model.add(Conv2D(32, 3, 3, input_shape = (32, 32, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(1000, activation='relu'))
model.add(Dense(1000, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(10, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train,to_categorical(y_train), epochs = 15, verbose = 1)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 56s 35ms/step - loss: 1.8867 - accuracy: 0.4097
# Epoch 2/15
# 1563/1563 [==============================] - 53s 34ms/step - loss: 1.3413 - accuracy: 0.5227
# Epoch 3/15
# 1563/1563 [==============================] - 52s 33ms/step - loss: 1.2103 - accuracy: 0.5760
# Epoch 4/15
# 1563/1563 [==============================] - 54s 35ms/step - loss: 1.1066 - accuracy: 0.6129
# Epoch 5/15
# 1563/1563 [==============================] - 52s 33ms/step - loss: 1.0024 - accuracy: 0.6529
# Epoch 6/15
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.8975 - accuracy: 0.6909
# Epoch 7/15
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.7786 - accuracy: 0.7333
# Epoch 8/15
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.6787 - accuracy: 0.7662
# Epoch 9/15
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.5760 - accuracy: 0.8029
# Epoch 10/15
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.4764 - accuracy: 0.8351
# Epoch 11/15
# 1563/1563 [==============================] - 52s 34ms/step - loss: 0.4057 - accuracy: 0.8610
# Epoch 12/15
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.3545 - accuracy: 0.8791
# Epoch 13/15
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.2988 - accuracy: 0.8999
# Epoch 14/15
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.2732 - accuracy: 0.9098
# Epoch 15/15
# 1563/1563 [==============================] - 49s 31ms/step - loss: 0.2461 - accuracy: 0.9202

# %%
model.evaluate(x_test, y_test)
